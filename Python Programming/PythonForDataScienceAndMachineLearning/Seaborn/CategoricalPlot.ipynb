# %%
import seaborn as sns
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as mp

# %%
tips = sns.load_dataset('tips')
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.barplot(x='sex',y='total_bill',data=tips)
plt.show()

# %%
#Standard deviation
sns.barplot(x='sex',y='total_bill',data=tips, estimator=np.std)
plt.show()

# %%
sns.countplot(x='sex',data=tips)
plt.show()

# %%
sns.boxplot(x="day", y="total_bill", data=tips,palette='rainbow')
plt.show()
# Out:
# C:\Users\NathaliaSungkoora\AppData\Local\Temp\ipykernel_37784\3065733212.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x="day", y="total_bill", data=tips,palette='rainbow')

# %%
sns.violinplot(x="day", y="total_bill", data=tips)
plt.show()

# %%
sns.violinplot(x="day", y="total_bill", data=tips,hue='sex',palette='Set1') 
plt.show()

# %%
sns.violinplot(x="day", y="total_bill", data=tips,hue='sex',split=True,palette='Set1')
plt.show()

# %%
sns.stripplot(x="day", y="total_bill", data=tips)
plt.show()

# %%
sns.stripplot(
    x="day", 
    y="total_bill", 
    data=tips,
    jitter=True,
    hue='sex',
    palette='Set1'
)
plt.show()

# %%
sns.swarmplot(x="day", y="total_bill", data=tips)
plt.show()

# %%
sns.violinplot(x="day", y="tip", data=tips,palette='rainbow')
sns.swarmplot(x="day", y="tip", data=tips,color='black',size=3)
plt.show()
# Out:
# C:\Users\NathaliaSungkoora\AppData\Local\Temp\ipykernel_37784\799644067.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(x="day", y="tip", data=tips,palette='rainbow')

# %%
sns.catplot(x='sex', y='total_bill', data=tips, kind='bar')
plt.show()
